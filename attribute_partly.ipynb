# %%
#对人脸做对齐
# !python partly_pre_process.py
# Out:
# loading data/CASIA-WebFace-partly.pkl...
# num_items: 1304
# ...
#   0%|                                          | 1/1304 [00:00<02:21,  9.20it/s]data/CASIA-WebFace-test/0000045/001.jpg
# data/CASIA-WebFace-test/0000045/015.jpg
# data/CASIA-WebFace-test/0000045/010.jpg
# data/CASIA-WebFace-test/0000045/011.jpg
# data/CASIA-WebFace-test/0000045/005.jpg
#   0%|▏                                         | 6/1304 [00:00<01:47, 12.09it/s]data/CASIA-WebFace-test/0000045/013.jpg
# data/CASIA-WebFace-test/0000045/007.jpg
# data/CASIA-WebFace-test/0000045/006.jpg
# data/CASIA-WebFace-test/0000045/012.jpg
# data/CASIA-WebFace-test/0000045/008.jpg
#   1%|▎                                        | 11/1304 [00:00<01:24, 15.36it/s]data/CASIA-WebFace-test/0000045/009.jpg
# data/CASIA-WebFace-test/0000100/016.jpg
# data/CASIA-WebFace-test/0000100/002.jpg
# data/CASIA-WebFace-test/0000100/003.jpg
# data/CASIA-WebFace-test/0000100/017.jpg
# ...

# %%
import pickle
with open('data/CASIA-WebFace--partly-aligned.pkl', 'rb') as file:
    data = pickle.load(file)
    sample = data['samples']
    print(len(sample))
# Out:
# 1303

# %%
# !python partly-train.py
# Out:
# 2019-12-19 08:32:40,844 INFO 	Epoch: [0][0/37]	Loss 16.4116 (16.4116)	Reg Loss 12.0418 (12.0418)	Expression Accuracy 31.2500 (31.2500)	Gender Accuracy 59.3750 (59.3750)	Glasses Accuracy 31.2500 (31.2500)	Race Accuracy 31.2500 (31.2500)
# 2019-12-19 08:32:51,348 INFO 	Validation: Loss 22.9816	Reg Loss 23.1742 (19.8610)	Expression Accuracy 66.6667 (59.5833)	Gender Accuracy 0.0000 (19.3750)	Glasses Accuracy 66.6667 (59.5833)	Race Accuracy 66.6667 (59.5833)
#
# 2019-12-19 08:32:52,185 INFO 	Epoch: [1][0/37]	Loss 26.1538 (26.1538)	Reg Loss 23.3005 (23.3005)	Expression Accuracy 81.2500 (81.2500)	Gender Accuracy 65.6250 (65.6250)	Glasses Accuracy 81.2500 (81.2500)	Race Accuracy 81.2500 (81.2500)
# 2019-12-19 08:33:02,631 INFO 	Validation: Loss 7.9859	Reg Loss 4.5524 (3.9857)	Expression Accuracy 66.6667 (59.5833)	Gender Accuracy 0.0000 (1.8750)	Glasses Accuracy 66.6667 (59.5833)	Race Accuracy 66.6667 (59.5833)
#
# ...

# %%
# !python partly-demo.py
# Out:
# 0000099_037.jpg
# 0000099_243.jpg
# 0000099_121.jpg
# 0000099_123.jpg
# 0000099_222.jpg
# 0000099_095.jpg
# 0000099_257.jpg
# 0000099_227.jpg
# 0000099_082.jpg
# 0000099_036.jpg
# torch.Size([10, 5])
# expression_out.size(): torch.Size([10, 1])
# gender_out.size(): torch.Size([10, 1])
# glasses_out.size(): torch.Size([10, 1])
# race_out.size(): torch.Size([10, 1])
# expression_out.shape: (10, 1)
# gender_out.shape: (10, 1)
# glasses_out.shape: (10, 1)
# race_out.shape: (10, 1)
