# %%
#对人脸做对齐
# !python partly_pre_process.py
# Out:
# loading data/CASIA-WebFace-partly.pkl...
# num_items: 1374
#   0%|                                                  | 0/1374 [00:00<?, ?it/s]/Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/002.jpg
# not enough values to unpack (expected 2, got 0)
# /Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/003.jpg
# not enough values to unpack (expected 2, got 0)
# /Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/001.jpg
# not enough values to unpack (expected 2, got 0)
# /Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/015.jpg
# not enough values to unpack (expected 2, got 0)
# /Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/014.jpg
# not enough values to unpack (expected 2, got 0)
# /Users/yulin9/Documents/project/AI/dataset/CASIA-WebFace-test/0000045/004.jpg
# not enough values to unpack (expected 2, got 0)
# ...
